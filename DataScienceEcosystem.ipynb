# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>Data Science Tools and Ecosystem</h1>

# %% [markdown]
# <p>In this notebook, Data Science Tools and Ecosystem are summarized.</p>

# %% [markdown]
# <b>Some of the popular languages that Data Scientists use are:</b>
#
# <ol>
# <li>SQL</li>
# <li>Python</li>
# <li>R</li>
# </ol>

# %% [markdown]
# <b>Some of the commonly used libraries used by Data Scientists include</b>
#
# <ol>
# <li>NumPy</li>
# <li>TensorFlow</li>
# <li>SciPy</li>
# <li>Pytorch</li>
# </ol>

# %% [markdown]
# <table>
#   <tr>
#     <th>Data Science Tools</th>
#   </tr>
#   <tr>
#     <td>Apache Spark</td>
#   </tr>
#     <tr>
#     <td>RStudio</td>
#   </tr>
#   <tr>
#     <td>Jupyter Notebook</td>
#   </tr>
# </table>

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python</h3>

# %%
eval = (3*4)+5
print(eval)
print(eval==17)

# %%
print(200 / 6)

Output: 33.333333333333336

# %% [markdown]
# <b>Objectives:</b><p>List popular languages for Data Science.</p>
#
# <ol>
# <li>R</li>
# <li>SQL</li>
# <li>Python</li>
# </ol>

# %% [markdown]
# <h3>Author</h3>
# <p>Name: Rizwan Yaseen</p>
